# %%
import pandas as pd

games_filename = "games.csv"
games = pd.read_csv(games_filename)

counts = games["Winner"].value_counts()

df = pd.DataFrame({'winner':counts.keys().tolist(), 'val':counts.tolist()})
ax = df.plot.bar(x='winner', y='val', rot=0)
